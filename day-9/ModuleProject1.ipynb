# %%
# Generate Random Numbers
# Check which numbers are even/odd
# rounds number using math
# count how many times number appear
# Saves the result in a file

# %%
import random
import math
import os
import re
from collections import Counter
#Generating Random Numbers
numbers = [random.randint(1,20) for i in range(10)]
#Checking odd or even
for i in numbers: 
    ab = int(i)
    if ab%2 == 0:
        print(ab,"Even")
    else:
        print(ab, "Odd")

# rounds number using math
for nums in numbers:
    print("Round is:",round(nums))
    print("Ceil is:",math.ceil(nums))
    print("Floor is:",math.floor(nums))
if
# Out:
# 5 Odd
# 1 Odd
# 6 Even
# 11 Odd
# 12 Even
# 6 Even
# 6 Even
# 16 Even
# 5 Odd
# 13 Odd
# Round is: 5
# Ceil is: 5
# Floor is: 5
# Round is: 1
# Ceil is: 1
# Floor is: 1
# Round is: 6
# Ceil is: 6
# Floor is: 6
# Round is: 11
# Ceil is: 11
# Floor is: 11
# Round is: 12
# Ceil is: 12
# Floor is: 12
# Round is: 6
# Ceil is: 6
# Floor is: 6
# Round is: 6
# Ceil is: 6
# Floor is: 6
# Round is: 16
# Ceil is: 16
# Floor is: 16
# Round is: 5
# Ceil is: 5
# Floor is: 5
# Round is: 13
# Ceil is: 13
# Floor is: 13

# %%
n1 = "Abhi"
n2 = "Ram"
print(n1.join(n2))
# Out:
# RAbhiaAbhim
