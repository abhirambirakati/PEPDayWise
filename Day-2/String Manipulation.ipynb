# %%
s = " Python Programming "
print(len(s))
print(s[-1])
print(s[:4])
print(s[7:18])
print(s.lower())
print(s.upper())
print(s.strip())
print(s.replace("Python", "java"))
print(s.find("a"))
words  = s.split()
print(words)
a = "abc"
print(a.isalpha())
b = "asd"
print(b.isdigit())
# Out:
# 20
#
#  Pyt
#  Programmin
#  python programming
#  PYTHON PROGRAMMING
# Python Programming
#  java Programming
# 13
# ['Python', 'Programming']
# True
# False

# %%
s = "my name is abhiram"

count = 0
for i in s:
    if i in 'aeioe':
        count+=1
else:
    print(count)
# Out:
# 6

# %%
 a = "1221"
 if a == a[::-1]:
     print("Its a plaindrome")
 else: 
     print("its not a ")
# Out:
# Its a plaindrome

# %%
#replace vowel with star
s = "Python"
result = " "
for ch in s:
    if ch in 'aeiou':
        result+="*"
    else:
        result+=ch
print(result)
# Out:
#  Pyth*n

# %%
77777
