# %%
# creating a new file and writing the information what we need
# file = open("Students1.txt","w")
# file.write("Name: Abhiram \n")
# file.write("Course: Python \n")
# file.close()

# %%
#Reading the file and printing the informartion what is inside it
# file = open("Students1.txt", "r")
# data = file.read()
# print(data)
# file.close()
# Out:
# Name: Abhiram
# Course: Python

# %%
# file = open("Students1.txt",  "a")
# file.write("Marks : 90 \n")
# file.close
# Out:
# <function TextIOWrapper.close()>

# %%
# file = open("Students1.txt", "r")
# data = file.readlines()
# print(data)
# Out:
# ['Name: Abhiram \n', 'Course: Python \n']

# %%
# file = open("Data.txt", "w")
# file.write("Name: Abhi \n")
# file.write("City: Srikakulam \n")
# file.close()
# file = open("Data.txt", "a")
# file.write("Age : 20")
# file.close()
# file = open("Data.txt", "r")
# data = file.readlines()
# print(len(data))
# print(data)
# Out:
# 3
# ['Name: Abhi \n', 'City: Srikakulam \n', 'Age : 20']

# %%
# file = open("Stundent.txt","r")
# data = file.read()
# print(data.upper())
# Out:
# MY NAME IS ABHIRAM

# %%
# file = open("Stundent.txt", "r")
# data = file.read()
# words = data.split()
# print("Total Words in a file:", len(words))
# file.close()

# %%
# file = open("Stundent.txt", "r")
# data = file.read()
# count = data.lower().count("abhiram")
# print("Count Words",count)
# file.close()

# %%
# file = open("Stundent.txt", "r")
# data = file.read()
# reverse = data[::-1]
# print(reverse)
# file.close()
# Out:
#  marihba
# marihbA
# upl ni gniydutS mi
# marihbA si eman yM

# %%
# file = open("Stundent.txt", "r")
# data = file.read()
# replaced = data.replace("Abhiram","Kohli")
# print(replaced)
# Out:
# My name is Kohli
# im Studying in lpu
# Kohli
# abhiram

# %%
# file = open("Movies.txt", "w")
# file.write("Movie1 : Bahubali \n")
# file.write("Movie2 : Pushpa \n")
# file.write("Movie3 : Spirit \n")
# file.close()

# %%
# file = open("Movies.txt", "r")
# data = file.read()
# tenchar = data[:10]
# print(tenchar)
# file.close()
# Out:
# Movie1 : B

# %%
file = open("Movies.txt", "r")
data = file.read()
words = data.split()
for w in words:
    print(w[::-1])
file.close()
# Out:
# 1eivoM
# :
# ilabuhaB
# 2eivoM
# :
# aphsuP
# 3eivoM
# :
# tiripS
