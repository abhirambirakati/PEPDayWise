# %%
def chenna():
    print("Adu eripuku")

chenna()
def add(a,b):
    return (a+b)

print("The sum is" ,add(5,6))
# Out:
# Adu eripuku
# The sum is 11

# %%
#lamda Functrion  = a Lambda function is a small, anonymous function. It is called "anonymous" because, 
#unlike a regular function, it is defined without a name using the lambda keyword instead of def
#Square
a = lambda x: x*x
print(a(5))

#Sum
bc = lambda xy,yx:xy+yx
print(bc(2,3))
# Out:
# 25
# 5
