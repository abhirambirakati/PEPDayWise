# %%
# take input print its type and then print double of it
a = input("Enter Something")
# Out:
# Enter Something

# %%
ab = str(input("Enter Salary"))
bc = int(ab)
final_salary = bc + 5000
print(final_salary)
# Out:
# Enter Salary 50000
# 55000

# %%
a = int(input("Enter Temperature:"))
if a>= 30:
    print("Hot")
elif a>=15:
    print("Normal")
else:
    print("Cool")
# Out:
# Enter Temperature: 26
# Normal

# %%
#while loop
num = int(input("Enter a number"))
i = 1
count = 0
while(i<=10):
    print(num,"X",i,"=",num * i)
    i+=1
    count+=1

print(count)
# Out:
# Enter a number 6
# 6 X 1 = 6
# 6 X 2 = 12
# 6 X 3 = 18
# 6 X 4 = 24
# 6 X 5 = 30
# 6 X 6 = 36
# 6 X 7 = 42
# 6 X 8 = 48
# 6 X 9 = 54
# 6 X 10 = 60
# 10

# %%
#take a number and reverse it
a = int(input("Enter a number"))
b = a.reverse_number_math(a)
print(a)
# Out:
# Enter a number 456
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 3
#       1 #take a number and reverse it
#       2 a = int(input("Enter a number"))
# ----> 3 b = a.reverse_number_math(a)
#       4 print(a)
#
# AttributeError: 'int' object has no attribute 'reverse_number_math'

# %%
x = input("Enter a Number")
a = lambda x: x*x*x
print(a(x))
# Out:
# Enter a Number 18
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 3
#       1 x = input("Enter a Number")
#       2 a = lambda x: x*x*x
# ----> 3 print(a(x))
#
# Cell In[12], line 2, in <lambda>(x)
#       1 x = input("Enter a Number")
# ----> 2 a = lambda x: x*x*x
#       3 print(a(x))
#
# TypeError: can't multiply sequence by non-int of type 'str'

# %%
#take a number and reverse it using loop
#Check even or odd functions
