# %%
print("Hello World")
# Out:
# Hello World

# %%
a = "Abhi"
print(a)
# Out:
# Abhi

# %%
inta = 23
floatb = 18.88
Stringc = "Abhiram"
c = inta>floatb
print(inta,floatb,Stringc,c)
print(type(inta))
# Out:
# 23 18.88 Abhiram True
# <class 'int'>
