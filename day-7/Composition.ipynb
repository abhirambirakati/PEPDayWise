# %%
class Address:
    def __init__(self, city):
        self.city = city
    def show_address(self):
        print("City", self.city)

#Student Class
class Student:
    def __init__(self, name, city):
        self.name = name
        #Composition :
        #Creating object of address class inside Student class
        self.address = Address(city)
    def show_student(self):
        print("name:" , self.name)
        self.address.show_address()

s = Student("Ab", "psa")
s.show_student()
# Out:
# name: Ab
# City psa

# %%
#Create a class engine and then create a class car
#car has-a engine

# %%
class Engine:
    def info1(self):
        print("car is started:")
class Car:
    def __init__(self):
        self.Engine = Engine()
        
    def drive(self):
        self.Engine.info1()
obj = Car()

# %%
create a teacher and student classes where teacher HAS-A subject
