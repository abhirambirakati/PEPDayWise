# %%
# Abstraction - Shows only the needed hide the rest
# 1.Define Rules
# 2.show what to do
# 3.hides how to do
# 4.uses in big problem
#

# %%
#Abstract Class - method name is present and method body is absent and child class will complete method body

# %%
class Payment:
    def start(self):
        print("do payment as ur wish")
    def pay(self, amount):
        pass
class UPI(Payment):
    def pay(self, amount):
        print("Paid using upi", amount)
class Card(Payment):
    def pay(self, amount):
        print("Paid using card", amount)
class Cash(Payment):
    def pay(self, amount):
        print("Paid using cash", amount)

u1 = UPI()
c1 = Card()
c2 = Cash()
# u1.pay(1000)
# c1.pay(1000)
c2.start()
c2.pay(1000)
# Out:
# do payment as ur wish
# Paid using cash 1000

# %%
class Shape:
    def start(self):
        print("Enter Type u want")
    def drawing(self, leng, brea):
        pass
class Rect(Shape):
    def drawing(self, leng, brea):
        area = leng*brea
        print("its area of rect",area )
class square(Shape):
    def drawing(self, leng, brea):
        squ = leng*leng
        print("its area of square is ",squ)
class tria(Shape):
    def drawing(self, leng, brea):
        areatri = 0.5*leng*brea
        print("its area of triangle is", areatri)


t1 = tria()
t1.start()
t1.drawing(3,4)
# Out:
# Enter Type u want
# its area of triangle is 6.0
