# %%
s = {1,2,2,3,4,3}
print(len(s))
# Out:
# 4

# %%
i = 1
while i < 10:
    i*=3
    print(i)
# Out:
# 3
# 9
# 27

# %%
for i in range(3):
    print(i)
else:
    print("Done")
# Out:
# 0
# 1
# 2
# Done

# %%
try:
    print("A")
    10/0
    print("B")
except:
    print("C")
print("D")
# Out:
# A
# C
# D

# %%
try:
    print(1)
except:
    print(2)
finally:
    print(3)
# Out:
# 1
# 3

# %%
def test():
    try:
        return 10
    finally:
        return 12

print(test())
# Out:
# 12

# %%
#1 Move all the zeroes to the end 
# given a list we need move all zeroes to last
nums = [0,1,0,3,12]
result = []
zero_count = 0
for n in nums:
    if n==0:
        zero_count+=1
    else:
        result.append(n)

for i in range(zero_count):
    result.append(0)
print(result)
# Out:
# [1, 3, 12, 0, 0]

# %%
text = "naman"
left = 0
right = len(text) - 1
is_palindrome = True
while left < right:
    if text[left] != text[right]:
        is_palindrome=False
        break
        left+=1
        right-=1
print(is_palindrome)

# %%
Sentence = "Python makes Problem Solving fun"
words = Sentence.split()
longest = ""
for i in words:
    if len(i)>len(longest):
        longest = i
print(longest)

# %%
Sentence = "Python makes Problem Solving fun"
words = Sentence.split()
longest = ""
for i in words:
    if len(i)>len(longest):
        longest = i
print(longest)
# Out:
# Problem

# %%
nums = [1,2,3,2]
target = 5
count = 0
for i in range(len(nums)):
    total = 0
    for j in range(i,len(nums)):
        total+=nums[j]
        if total == target:
            count+=1
print(count)
# Out:
# 2

# %%
nums = [2,7,11,15]
target = 9
for i in range(len(nums)):
    for j in range(i+1,len(nums)):
        if nums[i]+nums[j]==target:
            print(nums[i],nums[j])
# Out:
# 2 7

# %%
nums = [2,7,11,15]
target = 9
left = 0
right = len(nums)-1
while left < right:
    current_sum = nums[left]+nums[right]
    if current_sum == target:
        print(nums[left],nums[right])
        break
    elif current_sum < target:
        left +=1
    else:
        right -=1
# Out:
# 2 7
